# %% [markdown]
# # Part 2: What is by baby saying?
#
# First of all...
#
#   **Congrats on making it this far!**
#
# Now time for the next half: What is my baby saying?
#
# There's a scrambled audio file located with this IPython Notebook. Can you unscramble it before time runs out?
#
#
# Good luck!

# %%
from scipy import signal
from scipy.io import wavfile
from IPython.display import Audio as IPAudio

fs, scrambled_tune = wavfile.read("scramble.wav")

IPAudio(scrambled_tune, rate = fs)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
